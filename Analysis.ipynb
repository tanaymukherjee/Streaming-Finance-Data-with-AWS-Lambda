# 68    SQ   72.81     9  05/14/2020 09:46:00           1
# 69    SQ   75.59    10  05/14/2020 10:59:00           1
# 70    SQ   76.49    11  05/14/2020 11:09:00           1
# 71    SQ   76.75    12  05/14/2020 12:59:00           1
# 72    SQ   77.18    13  05/14/2020 13:48:00           1
# 73    SQ   77.26    14  05/14/2020 14:59:00           1
# 74    SQ   78.25    15  05/14/2020 15:57:00           1
# 75   TTD  289.45     9  05/14/2020 09:31:00           1
# 76   TTD  290.07    10  05/14/2020 10:53:00           1
# 77   TTD  296.86    11  05/14/2020 11:18:00           1
# 78   TTD  294.50    12  05/14/2020 12:57:00           1
# 79   TTD  296.00    13  05/14/2020 13:31:00           1
# 80   TTD  295.77    14  05/14/2020 14:59:00           1
# 81   TTD  297.67    15  05/14/2020 15:24:00           1
#
# [82 rows x 5 columns]

# %% [markdown]
# ### Visualizations

# %%
## 1. Line plot for all stocks for the whole day on 14th May, 2020 by hour
## With same x-axis and same y-axis

plt.figure(figsize=(16,8))
plt.title('Highest stock by hour for each firm on 14th May, 2020')
sns.lineplot(x='Hour',y='High',hue='Name',data=df)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
## 2. Line plot for all stocks for the whole day on 14th May, 2020 by hour
## With same x-axis and different y-axis

df = df[['Name','High','Hour']]

for i in df['Name'].unique():
    plot = df[df['Name'] == i]
    plot.set_index('Hour').plot(kind='line')
    plt.title(f'Change of stock by hour {i}')
    plt.show()

# %%
## 3. Violin chart showing distrubution range of high stocks for all companies together for 14th May, 2020 by each hour.

plt.figure(figsize=(10,6))
 
sns.violinplot(x='Hour',
               y='High', 
               data=df, 
               inner=None, 
               palette='colorblind')
 
sns.swarmplot(x='Hour', 
              y='High', 
              data=df, 
              color='k',
              alpha=0.7) 
 
# Set title with matplotlib
plt.title('Range of hourly high stock for each hour by all companies combined')
# Out:
# Text(0.5, 1.0, 'Range of hourly high stock for each hour by all companies combined')

# %%
## Pivoting the table to group all the data for a bar c

df_pivot = df.pivot_table('High', ['Name'], 'Hour')
df_pivot
# Out:
# Hour      9       10      11      12      13      14      15
# Name
# BYND  137.97  139.56  141.00  138.24  137.79  135.73  135.85
# DDOG   67.25   66.55   65.00   64.88   65.00   64.13   65.87
# FB    203.87  203.35  204.27  205.10  205.64  204.99  206.93
# NFLX  452.00  446.51  440.64  440.34  441.78  441.44  442.14
# OKTA  178.00  177.81  179.89  179.01  178.50  177.81  177.85
# PINS   16.54   16.67   16.94   17.04   17.03   16.91   17.09
# SHOP  758.09  752.00  757.47  754.16  755.82  751.80  755.57
# SNAP   16.73   16.93   17.15   16.99   17.00   16.92   16.97
# SQ     72.81   75.59   76.49   76.75   77.18   77.26   78.25
# TTD   289.45  290.07  296.86  294.50  296.00  295.77  297.67

# %%
## 4. Grouped bar plot

sns.set(style="whitegrid")

# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="Hour", y="High", hue="Name", data=df,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("High Stock Per Hour")
